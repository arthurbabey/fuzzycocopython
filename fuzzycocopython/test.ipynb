# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from fuzzycocopython.model import FuzzyModel
from fuzzycocopython.params import Params

# %%
data = pd.read_csv('/Users/arthurbabey/Projects/FuzzyCoCo/fuzzycoco/Release/iris36.csv', sep=';')
X_train, X_test = train_test_split(data, test_size=0.5, random_state=1)

# %%
X_test
# Out:
#          CASE  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  OUT
# 30  subject81           7.4          2.8           6.1          1.9    1
# 34  subject90           6.9          3.1           5.4          2.1    1
# 28  subject77           6.2          2.8           4.8          1.8    1
# 3    subject5           5.0          3.6           1.4          0.2    0
# 19  subject53           7.1          3.0           5.9          2.1    1
# 17  subject47           5.1          3.8           1.6          0.2    0
# 21  subject57           4.9          2.5           4.5          1.7    1
# 23  subject61           6.5          3.2           5.1          2.0    1
# 29  subject80           7.2          3.0           5.8          1.6    1
# 26  subject74           6.3          2.7           4.9          1.8    1
# 27  subject76           7.2          3.2           6.0          1.8    1
# 33  subject87           6.3          3.4           5.6          2.4    1
# ...

# %%
X_train
# Out:
#          CASE  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  OUT
# 32  subject83           6.4          2.8           5.6          2.2    1
# 22  subject59           6.7          2.5           5.8          1.8    1
# 31  subject82           7.9          3.8           6.4          2.0    1
# 20  subject54           6.3          2.9           5.6          1.8    1
# 18  subject51           6.3          3.3           6.0          2.5    1
# 6   subject14           4.3          3.0           1.1          0.1    0
# 13  subject34           5.5          4.2           1.4          0.2    0
# 7   subject16           5.7          4.4           1.5          0.4    0
# 35  subject99           6.2          3.4           5.4          2.3    1
# 1    subject3           4.7          3.2           1.3          0.2    0
# 16  subject40           5.1          3.4           1.5          0.2    0
# 0    subject2           4.9          3.0           1.4          0.2    0
# ...

# %%
params = Params(seed=123)
model = FuzzyModel(params)

model = FuzzyModel(params)
model.fit(X_train)
predictions = model.predict(X_train)
predictions
# Out:
# ##========================================================================
# ##FuzzyCocoScriptRunner::run()
# ## params: Fuzzy Coco Params:
# ...
# Global params:
# | nb_rules | nb_max_var_per_rule | max_generations | max_fitness | nb_cooperators |
# |----------|---------------------|-----------------|-------------|----------------|
#         3 |                   3 |             100 |           0 |              2 |
#
# Input Variables:
# | nb_sets | nb_bits_vars | nb_bits_sets | nb_bit_pos |
# |---------|--------------|--------------|------------|
#        2 |            7 |            2 |          8 |
#
# Output Variables:
# | nb_sets | nb_bits_vars | nb_bits_sets | nb_bit_pos |
# |---------|--------------|--------------|------------|
#        2 |            1 |            1 |          1 |
#
# defuzz threshold:ACTIVATED
# output_vars_defuzz_thresholds:{0.5}
# Rules params
# | pop_size | elite_size | cx_prob | mut_flip_genome | mut_flip_bit |
# ...
